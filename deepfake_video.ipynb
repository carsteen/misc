# %%
# !!pip install deep-animator
# !!pip install fastscript
# !!pip install -U PyYAML
# Out:
# ['Collecting PyYAML',
#  '\x1b[?25l  Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)',
#  '',
#  '\x1b[K     |█▏                              | 10kB 18.9MB/s eta 0:00:01',
#  '\x1b[K     |██▍                             | 20kB 1.8MB/s eta 0:00:01',
#  '\x1b[K     |███▋                            | 30kB 2.6MB/s eta 0:00:01',
#  '\x1b[K     |████▉                           | 40kB 3.4MB/s eta 0:00:01',
#  '\x1b[K     |██████                          | 51kB 2.1MB/s eta 0:00:01',
#  '\x1b[K     |███████▎                        | 61kB 2.5MB/s eta 0:00:01',
#  '\x1b[K     |████████▌                       | 71kB 2.9MB/s eta 0:00:01',
#  '\x1b[K     |█████████▊                      | 81kB 3.3MB/s eta 0:00:01',
#  '\x1b[K     |███████████                     | 92kB 2.5MB/s eta 0:00:01',
#  '\x1b[K     |████████████▏                   | 102kB 2.8MB/s eta 0:00:01',
# ...

# %%
# Fecth model weights

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.
#
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '1zqa0la8FKchq62gRJMMvDGVhinf3nBEx'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('/content/model_weights')

# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
# %%bash
# cp /gdrive/'My Drive'/autre/output.mp4 /content/output.mp4
# cp /gdrive/'My Drive'/autre/macron_recadre.jpg /content/macron_recadre.jpg
#
# cp /gdrive/'My Drive'/autre/coonfig.yaml /content/coonfig.yaml
#
# cp /gdrive/'My Drive'/autre/macmac.jpg /content/macmac.jpg
# cp /gdrive/'My Drive'/autre/mac_bouche_ferme.png /content/mac_bouche_ferme.png
#
#
# cp /gdrive/'My Drive'/autre/macmacokok.png /content/macmacokok.png
# cp /gdrive/'My Drive'/autre/new_source_reduced.mp4 /content/new_source_reduced.mp4
# cp /gdrive/'My Drive'/autre/new_source_reduced_lowbitrate.mp4 /content/new_source_reduced_lowbitrate.mp4
# cp /gdrive/'My Drive'/autre/new_source_reduced_lowfps.mp4 /content/new_source_reduced_lowfps.mp4
# cp /gdrive/'My Drive'/autre/new_source_veryveryreduced_orig.mp4 /content/new_source_veryveryreduced_orig.mp4
#
# cp /gdrive/'My Drive'/autre/new_source_pt1.mp4 /content/new_source_pt1.mp4
# cp /gdrive/'My Drive'/autre/new_source_pt2.mp4 /content/new_source_pt2.mp4

# %%
cp /gdrive/'My Drive'/autre/new_source_pt1_no_sound.mp4 /content/new_source_pt1_no_sound.mp4

# %%
# %%bash
# cp /gdrive/'My Drive'/autre/new_source_gray.mp4 /content/new_source_gray.mp4

# %% [markdown]
# Utilisation de deep animate :
#
#
# ```
# deep_animate <path_to_the_source_image> <path_to_the_driving_video> <path_to_yaml_conf> <path_to_model_weights>
# ```

# %%
# !deep_animate /content/macmacokok.png /content/new_source_pt1_no_sound.mp4 /content/coonfig.yaml /content/model_weights
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/deep_animate", line 8, in <module>
#     sys.exit(deep_animate())
#   File "/usr/local/lib/python3.6/dist-packages/fastscript/core.py", line 73, in _f
#     func(**args.__dict__)
#   File "/usr/local/lib/python3.6/dist-packages/deep_animator/cli.py", line 29, in deep_animate
#     driving_video = imageio.mimread(driving)
#   File "/usr/local/lib/python3.6/dist-packages/imageio/core/functions.py", line 292, in mimread
#     raise RuntimeError('imageio.mimread() has read over 256 MiB of '
# RuntimeError: imageio.mimread() has read over 256 MiB of image data.
# Stopped to avoid memory problems. Use imageio.get_reader() or memtest=False.

# %%
cp /content/generated_video.mp4 /gdrive/'My Drive'/autre/generated_vid_new_source.mp4

# %%
# !ls -l /content
# Out:
# total 749204
# -rw-r--r-- 1 root root      2749 Apr 26 12:51 adc.json
# -rw------- 1 root root       619 Apr 26 12:55 coonfig.yaml
# -rw-r--r-- 1 root root   1394458 Apr 26 13:50 generated_video.mp4
# -rw------- 1 root root    243306 Apr 26 12:55 mac_bouche_ferme.png
# -rw------- 1 root root      3769 Apr 26 12:55 macmac.jpg
# -rw------- 1 root root    610531 Apr 26 12:55 macmacokok.png
# -rw------- 1 root root      7421 Apr 26 12:55 macron_recadre.jpg
# -rw-r--r-- 1 root root 728766691 Apr 26 12:52 model_weights
# -rw------- 1 root root   2570684 Apr 26 14:04 new_source_gray.mp4
# -rw------- 1 root root  14598803 Apr 26 12:55 new_source.mp4
# -rw------- 1 root root   1245061 Apr 26 14:10 new_source_pt1.mp4
# -rw------- 1 root root    405816 Apr 26 14:14 new_source_pt1_no_sound.mp4
# -rw------- 1 root root   1295029 Apr 26 14:01 new_source_pt2.mp4
# -rw------- 1 root root   2220421 Apr 26 13:09 new_source_reduced_lowbitrate.mp4
# ...

# %%
# !ls /content/'Vidéo source bonne orientation - anniv nonoch.mp4'
# Out:
# '/content/Vidéo source bonne orientation - anniv nonoch.mp4'

# %%
# !pip show deep-animator
# Out:
# Name: deep-animator
# Version: 0.1.1
# Summary: Image animation given a driving video sequence and a source image.
# Home-page: https://github.com/dpoulopoulos/deep_animator
# Author: Dimitris Poulopoulos
# Author-email: dimitris.a.poulopoulos@gmail.com
# License: Apache Software License 2.0
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: matplotlib, torchvision, torch, tqdm, numpy, Pillow, scikit-learn, pandas, scikit-image, scipy, imageio, ffmpeg, fire
# Required-by:

# %%
import numpy as np 
aa = np.array(['lal'])

# %%
# !!cat /usr/local/lib/python3.6/dist-packages/imageio/core/functions.py
# Out:
# ['# -*- coding: utf-8 -*-',
#  '# imageio is distributed under the terms of the (new) BSD License.',
#  '',
#  '"""',
#  "These functions represent imageio's main interface for the user. They",
#  'provide a common API to read and write image data for a large',
#  'variety of formats. All read and write functions accept keyword',
#  'arguments, which are passed on to the format that does the actual work.',
#  'To see what keyword arguments are supported by a specific format, use',
#  'the :func:`.help` function.',
#  '',
#  'Functions for reading:',
#  '',
#  '  * :func:`.imread` - read an image from the specified uri',
#  '  * :func:`.mimread` - read a series of images from the specified uri',
#  '  * :func:`.volread` - read a volume from the specified uri',
#  '  * :func:`.mvolread` - read a series of volumes from the specified uri',
#  '',
#  'Functions for saving:',
#  '',
#  '  * :func:`.imwrite` - write an image to the specified uri',
# ...
